# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ###### with the help of geopandas we can access any 'shp' file.The shapefile format is a geospatial vector data format file where we can see that it consist of geometry column which typically tells about the dimension of any location

# %%
roads = gpd.read_file(r'C:\Users\user\Downloads\my work software\pandas\vinay\project for jobs\geographic project\IND_roads.shp')

# %%
roads.head()
# Out:
#        MED_DESCRI       RTT_DESCRI F_CODE_DES  ISO ISOCOUNTRY  \
# 0  Without Median  Secondary Route       Road  IND      INDIA
# 1  Without Median  Secondary Route       Road  IND      INDIA
# 2  Without Median  Secondary Route       Road  IND      INDIA
# 3  Without Median  Secondary Route       Road  IND      INDIA
# 4  Without Median  Secondary Route       Road  IND      INDIA
#
#                                             geometry
# 0  LINESTRING (77.82774 35.50128, 77.82575 35.49950)
# 1  LINESTRING (77.82373 35.50099, 77.82575 35.49950)
# 2  MULTILINESTRING ((77.82575 35.49950, 77.82975 ...
# 3  LINESTRING (77.93183 35.38539, 77.94247 35.379...
# 4  LINESTRING (77.93183 35.38539, 77.90347 35.381...

# %%
# now lets try to plot and see what this dataset is representing

# %%
roads.plot(cmap='jet', figsize=(10,10))
# this is the access of all different roads of india
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## now the column below is anothor shp file which consist of administrative areas of india

# %%
cities=gpd.read_file(r'C:\Users\user\Downloads\my work software\pandas\vinay\project for jobs\geographic project\New Folder (2)\IND_adm1.shp')

# %%
cities.head()
# Out:
#    ID_0  ISO NAME_0  ID_1               NAME_1          TYPE_1  \
# 0   105  IND  India     1  Andaman and Nicobar  Union Territor
# 1   105  IND  India     2       Andhra Pradesh           State
# 2   105  IND  India     3    Arunachal Pradesh           State
# 3   105  IND  India     4                Assam           State
# 4   105  IND  India     5                Bihar           State
#
#          ENGTYPE_1 NL_NAME_1  \
# 0  Union Territory      None
# 1            State      None
# 2            State      None
# 3            State      None
# 4            State      None
#
#                                            VARNAME_1  \
# 0  Andaman & Nicobar Islands|Andaman et Nicobar|I...
# 1                                               None
# 2  Agence de la Frontière du Nord-Est(French-obso...
# 3                                               None
# 4                                               None
#
#                                             geometry
# ...

# %%
#So lets try to plot the cities and see what it shows

# %%
import descartes

# %%
cities.plot(cmap='jet',column='NAME_1', figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
#we can aslo access any perticular city of our interest  as we are trying to access delhi here
com_id = cities[cities['NAME_1'] == 'Delhi']
com_id.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #So this is a way to access different geographical locations according to their coordinates with the help of shp files
#
# #now ther is a another method also where we can use arcgis library

# %%
import arcgis
from arcgis.gis import GIS
from IPython.display import display

# %%
mygis= GIS()
mymap= mygis.map()
mymap
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-5ae21466-0fd3-4c07-861e-bfe2c2f7cf58"><img src=""></img></div>

# %% [markdown]
#  ###### Arcgis enables you to connect with different locations you can Map your own locations and with the help of arcgis you can have different kind of maps according to your data exploration and visualization need

# %% [markdown]
# ###### so first what we can do with the arcgis is that we can access any location on the globe according to our need so lets try to locate the DELHI on the globe

# %%
my_map1= mygis.map('Delhi',10)
my_map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-79ac0a1e-5f36-482a-82ae-d58ca3c82772"><img src=""></img></div>

# %%
# this is doing some error in my computer but you can access geocode for any perticular locatoin on globe
location= geocode('Delhi')[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ab6614569ecf> in <module>
#       1 # this is doing some error in my computer but you can access geocode for any perticular locatoin on globe
# ----> 2 location= geocode('Delhi')[0]
#
# NameError: name 'geocode' is not defined

# %% [markdown]
# #### So i am again try to access delhi in the below column and then i want to locate a drawer onto 'Connaught Place'

# %%
m1=mygis.map('Delhi',10)
m1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-47e36672-45d7-41ca-8a3f-3e5933d3007f"><img src=""></img></div>

# %% [markdown]
# #### in the below column i am giving the coordinates for 'Connaught Place' but you can put the 'location'  variable i mentioned above in the code by that you are not just able to access 'Connaught Place' but any location by having the geocodes for that perticular location

# %%
m1.draw([28.6304, 77.2177])

# %%
# we can also have different kinds of basemaps 
m1.basemaps
# Out:
# ['dark-gray',
#  'dark-gray-vector',
#  'gray',
#  'gray-vector',
#  'hybrid',
#  'national-geographic',
#  'oceans',
#  'osm',
#  'satellite',
#  'streets',
#  'streets-navigation-vector',
#  'streets-night-vector',
#  'streets-relief-vector',
#  'streets-vector',
#  'terrain',
#  'topo',
#  'topo-vector']

# %%
m1.basemap='satellite'

# %%
## now as you can see the above map converts into beautiful 'satellite' map and we can see the high resolution image of any location
